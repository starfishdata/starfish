# %%
from starfish import data_gen_template

# %%
data_gen_template.list()
# Out:
# ['starfish/generate_func_call_dataset', 'starfish/generate_by_topic']

# %%
loaded = data_gen_template.get("starfish/generate_func_call_dataset")

# %% [markdown]
# get the template input_data schema and example

# %%
loaded.print_schema()
# Out:
# 2025-05-23 11:08:41 | INFO     | Please run the template with this input schema
# 2025-05-23 11:08:41 | INFO     | {
#     "$defs": {
#         "APIContract": {
#             "description": "Pydantic model representing an API contract structure.",
#             "properties": {
#                 "name": {
#                     "title": "Name",
#                     "type": "string"
#                 },
#                 "description": {
#                     "title": "Description",
#                     "type": "string"
#                 },
#                 "parameters": {
#                     "additionalProperties": {
#                         "$ref": "#/$defs/ParameterDefinition"
#                     },
#                     "title": "Parameters",
#                     "type": "object"
#                 }
#             },
#             "required": [
#                 "name",
#                 "description",
#                 "parameters"
#             ],
#             "title": "APIContract",
#             "type": "object"
#         },
#         "ParameterDefinition": {
#             "description": "Pydantic model representing parameter definition in an API contract.",
#             "properties": {
#                 "type": {
#                     "title": "Type",
#                     "type": "string"
#                 },
#                 "description": {
#                     "title": "Description",
#                     "type": "string"
#                 },
#                 "required": {
#                     "default": true,
#                     "title": "Required",
#                     "type": "boolean"
#                 }
#             },
#             "required": [
#                 "type",
#                 "description"
#             ],
#             "title": "ParameterDefinition",
#             "type": "object"
#         }
#     },
#     "description": "Input schema for the generate_by_topic template.\n\nIMPORTANT: This Pydantic model is the single source of truth for default values.\nThe validation and default values are controlled by this model, not the function signature.",
#     "properties": {
#         "num_records": {
#             "anyOf": [
#                 {
#                     "type": "integer"
#                 },
#                 {
#                     "type": "null"
#                 }
#             ],
#             "default": 10,
#             "title": "Num Records"
#         },
#         "api_contract": {
#             "$ref": "#/$defs/APIContract"
#         },
#         "topic_model_name": {
#             "default": "openai/gpt-4o-mini",
#             "title": "Topic Model Name",
#             "type": "string"
#         },
#         "topic_model_kwargs": {
#             "anyOf": [
#                 {
#                     "additionalProperties": true,
#                     "type": "object"
#                 },
#                 {
#                     "type": "null"
#                 }
#             ],
#             "default": null,
#             "title": "Topic Model Kwargs"
#         },
#         "generation_model_name": {
#             "default": "openai/gpt-4o-mini",
#             "title": "Generation Model Name",
#             "type": "string"
#         },
#         "generation_model_kwargs": {
#             "anyOf": [
#                 {
#                     "additionalProperties": true,
#                     "type": "object"
#                 },
#                 {
#                     "type": "null"
#                 }
#             ],
#             "default": null,
#             "title": "Generation Model Kwargs"
#         },
#         "data_factory_config": {
#             "anyOf": [
#                 {
#                     "additionalProperties": true,
#                     "type": "object"
#                 },
#                 {
#                     "type": "null"
#                 }
#             ],
#             "default": {},
#             "title": "Data Factory Config"
#         }
#     },
#     "required": [
#         "api_contract"
#     ],
#     "title": "GenerateFuncCallDataSet",
#     "type": "object"
# }

# %%
loaded.print_example()
# Out:
# 2025-05-23 11:09:02 | INFO     | Here is an example with api_contract.name as weather_api.get_current_weather
# 2025-05-23 11:09:02 | INFO     | {
#     "num_records": 4,
#     "api_contract": {
#         "name": "weather_api.get_current_weather",
#         "description": "Retrieves the current weather conditions for a specified location .",
#         "parameters": {
#             "location": {
#                 "type": "string",
#                 "description": "The name of the city or geographic location .",
#                 "required": true
#             },
#             "units": {
#                 "type": "string",
#                 "description": "The units for temperature measurement( e.g., 'Celsius', 'Fahrenheit') .",
#                 "required": false
#             }
#         }
#     },
#     "topic_model_name": "openai/gpt-4",
#     "topic_model_kwargs": {
#         "temperature": 0.7
#     },
#     "generation_model_name": "openai/gpt-4o-mini",
#     "generation_model_kwargs": {
#         "temperature": 0.8,
#         "max_tokens": 200
#     },
#     "data_factory_config": {
#         "max_concurrency": 24,
#         "task_runner_timeout": 120
#     }
# }

# %%
api_contract = {
            "name": "weather_api.get_current_weather",
            "description": "Retrieves the current weather conditions for a specified location .",
            "parameters": {
                "location": {"type": "string", "description": "The name of the city or geographic location .", "required": True},
                "units": {"type": "string", "description": "The units for temperature measurement( e.g., 'Celsius', 'Fahrenheit') .", "required": False},
            },
        }

data = await loaded.run(num_records=10, api_contract=api_contract)
# Out:
# 🌟 Function Calling Dataset Generation Pipeline
# ============================================================
# 📋 Process Overview:
#    1. Calculate optimal data distribution
#    2. Generate diverse topics
#    3. Create subtopics for each topic
#    4. Generate query-answer pairs
#    5. Verify and validate generated data
#    6. Regenerate failed cases
# ============================================================
# 📊 Data Distribution Plan:
#    • Requested: 10 records
#    • Distribution: 1 topics × 1 subtopics × 10 records
#    • Total generation: 10 records
#    • API calls needed: 3
#
# 🎯 Step 1: Generating diverse topics...
#    ✅ Generated 1 topics
#
# 🌿 Step 2: Creating subtopics for each topic...
# 2025-05-23 00:27:04 | INFO     | [JOB START] Master Job ID: e6763e50-6438-4df5-81a9-5a68ce3f8468 | Logging progress every 3 seconds
# 2025-05-23 00:27:04 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:06 | INFO     | [JOB FINISHED] Final Status: Completed: 1/1 | Attempted: 1 (Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
#    ✅ Generated 1 subtopics total
#
# 💬 Step 3: Generating query-answer pairs...
# 2025-05-23 00:27:06 | INFO     | [JOB START] Master Job ID: 1931c5c8-c1f3-4268-98b7-1a5295b8abf2 | Logging progress every 3 seconds
# 2025-05-23 00:27:06 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:09 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:12 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:15 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:18 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:21 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:24 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:27 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:28 | INFO     | [JOB FINISHED] Final Status: Completed: 1/1 | Attempted: 1 (Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
#    ✅ Generated 10 initial query-answer pairs
#
# 🔍 Step 4: Verifying data quality...
# 2025-05-23 00:27:28 | INFO     | [JOB START] Master Job ID: f036c07c-1cd2-4690-be92-bac359e45544 | Logging progress every 3 seconds
# 2025-05-23 00:27:28 | INFO     | [JOB PROGRESS] Completed: 0/10 | Running: 10 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:31 | INFO     | [JOB PROGRESS] Completed: 0/10 | Running: 10 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:34 | INFO     | [JOB PROGRESS] Completed: 9/10 | Running: 1 | Attempted: 9    (Completed: 9, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:35 | INFO     | [JOB FINISHED] Final Status: Completed: 10/10 | Attempted: 10 (Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:35 | WARNING  | Cannot serialize function for resume due to unsupported type: cannot pickle '_hashlib.HMAC' object
#    ✅ Quality check complete: 9 passed, 1 failed
#
# 🔄 Step 5: Regenerating failed cases...
# 2025-05-23 00:27:35 | INFO     | [JOB START] Master Job ID: 3d6183a2-e465-4807-9e18-cbb84dc0d28f | Logging progress every 3 seconds
# 2025-05-23 00:27:35 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:37 | INFO     | [JOB FINISHED] Final Status: Completed: 1/1 | Attempted: 1 (Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:37 | INFO     | [JOB START] Master Job ID: 8754bec6-25e3-40bd-9743-f2763fc1091f | Logging progress every 3 seconds
# 2025-05-23 00:27:37 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:40 | INFO     | [JOB PROGRESS] Completed: 0/1 | Running: 1 | Attempted: 0    (Completed: 0, Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:41 | INFO     | [JOB FINISHED] Final Status: Completed: 1/1 | Attempted: 1 (Failed: 0, Filtered: 0, Duplicate: 0, InDeadQueue: 0)
# 2025-05-23 00:27:41 | WARNING  | Cannot serialize function for resume due to unsupported type: cannot pickle '_hashlib.HMAC' object
#    ✅ Regenerated 1 pairs, 1 still failing
# 2025-05-23 00:27:41 | WARNING  | Some data still failing after regeneration - prompts may need improvement
# 🎯 Perfect! Generated exactly 10 records as requested
#
# 🎉 Generation Complete!
# ============================================================
# 📈 Final Results:
#    • Records generated: 10
#    • Success rate: 10/10 (100.0%)
#    • Distribution used: 1T × 1S × 10R
#
# ⭐ If you found this helpful, please consider starring our repo!
#    Your support means the world to us! 🌟
# ============================================================

# %%
data
# Out:
# [{'query': 'Can you check the current weather in Toronto and Rome? Use Fahrenheit for both locations.',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Toronto', 'units': 'Fahrenheit'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Rome', 'units': 'Fahrenheit'}}]},
#  {'query': 'Get me the current weather in Mumbai and also in Johannesburg, please use Fahrenheit for both.',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Mumbai', 'units': 'Fahrenheit'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Johannesburg', 'units': 'Fahrenheit'}}]},
#  {'query': 'I need the current weather for Sydney and London. What are the temperatures in Celsius?',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Sydney', 'units': 'Celsius'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'London', 'units': 'Celsius'}}]},
#  {'query': 'Please find the current weather in Buenos Aires and Cape Town, using Celsius for Buenos Aires.',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Buenos Aires', 'units': 'Celsius'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Cape Town'}}]},
#  {'query': 'What’s the weather like in Moscow? Also, can you get the current conditions in Beijing?',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Moscow'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Beijing'}}]},
#  {'query': 'Can you tell me the current weather in Tokyo and in Los Angeles? Please provide both in Fahrenheit.',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Tokyo', 'units': 'Fahrenheit'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Los Angeles', 'units': 'Fahrenheit'}}]},
#  {'query': 'Please provide the current weather for Berlin and Cairo, using Celsius for Berlin and no specific unit for Cairo.',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Berlin', 'units': 'Celsius'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Cairo'}}]},
#  {'query': 'I need the current weather in Seattle and in Santiago. Use Fahrenheit for Seattle and Celsius for Santiago.',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Seattle', 'units': 'Fahrenheit'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Santiago', 'units': 'Celsius'}}]},
#  {'query': "What's the current temperature in San Francisco? Can you also check the weather in Paris?",
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'San Francisco'}},
#    {'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'Paris'}}]},
#  {'query': 'What is the current weather in New York City? And can you also provide the temperature in Celsius?',
#   'answer': [{'name': 'weather_api.get_current_weather',
#     'arguments': {'location': 'New York City', 'units': 'Celsius'}}]}]
